# %% [markdown]
# ### Численное решение нелинейных уравнений и систем

# %% [markdown]
# Нелинейные уравнения и системы уравнений решаются с применением
# итерационных методов.
# $$\{x^0, x^1, x^2, ...\}$$

# %% [markdown]
# Поиск локализованного корня уравнения
# $$ f(x) = 0$$
# Системы
# $$
# \begin{cases}
# f_1(x_1, x_2,\dots,x_n)=0 \\
# f_2(x_1, x_2,\dots,x_n)=0 \\
# \dots \\
# f_n(x_1, x_2,\dots,x_n) = 0
# \end{cases} \quad \Leftrightarrow \quad f(x) = 0
# $$

# %% [markdown]
# #### Метод деления отрезка пополам (Бисекции) для скалярного уравнения
#
# Если $f$ непрерывна на отрезке $[a,\;b]$ и $f(a)f(b) < 0$, то существует $p \in [a,\;b]$ являющаяся корнем уравнения $f(x) = 0$.

# %% [markdown]
# На каждой итерации берется
# $$p = a + \frac{b - a}{2}$$
# Если $f(a)f(p) < 0$, то переходим к отрезку $[a_1,\;b_1] = [a,\;p]$, в противном случае к отрезку $[a_1,\;b_1] = [p,\;b]$ и т.д.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import matplotlib
matplotlib.rc("animation", html="jshtml")

a = [0.2]
b = [1.3]
p = []
f = lambda x: np.cos(x) - x ** 3 if x is not None else None

FA = f(a[-1])
for i in range(20):
    p.append(None)
    a.append(a[-1])
    b.append(b[-1])
    p.append(a[-1] + (b[-1] - a[-1]) / 2)
    FP = f(p[-1])
    if np.isclose(FP, 0.0, atol=0.001) or (b[-1] - a[-1]) / 2 < 0.1:
        break
    if np.sign(FA) * np.sign(FP) > 0:
        a.append(p[-1])
        b.append(b[-1])
        FA = FP
    else:
        a.append(a[-1])
        b.append(p[-1])

count = 0
subcount = 0
a_label = []
b_label = []
p_label = []
for _ in range(len(a)):
    a_label.append(r"$a_{}$".format(count))
    b_label.append(r"$b_{}$".format(count))
    p_label.append(r"$p_{}$".format(count))
    subcount += 1
    if subcount == 2:
        subcount = 0
        count += 1

fig, ax = plt.subplots(figsize=(7, 5))
# set the x-spine (see below for more info on `set_position`)
ax.spines["left"].set_position("zero")
# turn off the right spine/ticks
ax.spines["right"].set_color("none")
ax.yaxis.tick_left()
# set the y-spine
ax.spines["bottom"].set_position("zero")
# turn off the top spine/ticks
ax.spines["top"].set_color("none")
ax.xaxis.tick_bottom()

ax.set_xlim(-0.2, 2.0)
ax.set_ylim(-4, 4)

x = np.linspace(-1, 3, 100)

lines = []
lines.append(ax.plot(x, f(x), "k-", label=r"$\cos(x) - x^3$")[0])
lines.append(ax.plot([], [], "k--")[0])
lines.append(ax.plot([], [], "k--")[0])
lines.append(ax.plot([], [], "r--")[0])
lines.append(ax.text([], [], "", fontsize=20))
lines.append(ax.text([], [], "", fontsize=20))
lines.append(ax.text([], [], "", fontsize=20, color="r"))

ax.legend(loc='upper right');

true_count = 0


def animate(i):
    lines[1].set_data([a[i], a[i]], [0.0, f(a[i])])
    lines[2].set_data([b[i], b[i]], [0.0, f(b[i])])
    lines[3].set_data([p[i], p[i]], [0.0, f(p[i])])

    if f(a[i]) > 0:
        lines[4].set_y(f(a[i]) + 0.2)
    else:
        lines[4].set_y(0.2)

    if f(b[i]) > 0:
        lines[5].set_y(f(b[i]) + 0.2)
    else:
        lines[5].set_y(0.2)

    if p[i] is not None and f(p[i]) > 0:
        lines[6].set_y(f(p[i]) + 0.2)
    else:
        lines[6].set_y(0.2)

    if p[i] is not None:
        if np.isclose(a[i], p[i]):
            lines[4].set_text("")
        elif np.isclose(a[i], b[i]):
            lines[5].set_text("")
        lines[6].set_x(p[i] - 0.05)
        lines[6].set_text(p_label[i])
    else:
        lines[4].set_x(a[i] - 0.05)
        lines[5].set_x(b[i] - 0.05)
        lines[4].set_text(a_label[i])
        lines[5].set_text(b_label[i])
        lines[6].set_text("")

    return

plt.close("all")
ani1 = FuncAnimation(fig, animate, frames=len(a) - 2, interval=1600)
ani1
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img33f9a6ece77646a2b4865822b3d47031">
#     <br>
#     <input id="_anim_slider33f9a6ece77646a2b4865822b3d47031" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim33f9a6ece77646a2b4865822b3d47031.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim33f9a6ece77646a2b4865822b3d47031.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim33f9a6ece77646a2b4865822b3d47031.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim33f9a6ece77646a2b4865822b3d47031.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim33f9a6ece77646a2b4865822b3d47031.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim33f9a6ece77646a2b4865822b3d47031.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim33f9a6ece77646a2b4865822b3d47031.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim33f9a6ece77646a2b4865822b3d47031.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim33f9a6ece77646a2b4865822b3d47031.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim33f9a6ece77646a2b4865822b3d47031.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select33f9a6ece77646a2b4865822b3d47031" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img33f9a6ece77646a2b4865822b3d47031";
#     var slider_id = "_anim_slider33f9a6ece77646a2b4865822b3d47031";
#     var loop_select_id = "_anim_loop_select33f9a6ece77646a2b4865822b3d47031";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvIxREBQAAIABJREFUeJzt3XlYVGXjPvB7GEBCEBQEFVRAXBBk\
# HQW1wBU1xVRcKl/R3OrNUjPL1KzsFTU1NC1EMiW1Rc0FdwO3THs1CFLE1xITQSC2FCFBYJ7fH/2Y\
# b4QLKjNn5sz9ua65gjNnZm5Pc103z1meoxBCCBAREZGsmEgdgIiIiBoeC56IiEiGWPBEREQyxIIn\
# IiKSIRY8ERGRDLHgiYiIZIgFT0REJEMseCIiIhliwRMREckQC56IiEiGWPBEREQyxIInIiKSIRY8\
# ERGRDLHgiYiIZIgFT0REJEMseCIiIhliwRMREckQC56IiEiGWPBEREQyxIInIiKSIRY8ERGRDLHg\
# iYiIZIgFT0REJEMseCIiIhliwRMREckQC56IiEiGWPBEREQyxIInIiKSIRY8ERGRDLHgiYiIZIgF\
# T0REJEMseCIiIhliwRMREckQC56IiEiGWPBEREQyxIInIiKSIRY8ERGRDLHgiYiIZIgFr2XV1dXw\
# 8/PDkCFDpI5CRERGhAWvZR999BE8PDykjkFEREaGBa9F2dnZ2L9/PyZPnix1FCIiMjIseC2aOXMm\
# li1bBhMTbmYiItItNo+W7Nu3Dw4ODggICLjverGxsVCpVFCpVPD09NRROiIikjuFEEJIHUKO5s6d\
# i82bN8PU1BTl5eUoKSnBiBEjsGXLlnu+RqVSISkpSYcpiYhIrljwOnD8+HGsWLEC+/btu+96LHgi\
# Imoo3EVPREQkQxzB6xGO4ImIqKGYSh2AiIj+T2VlJbKzs1FeXi51FNmzsLCAs7MzzMzMpI6iFSx4\
# IiI9kp2dDWtra7i4uEChUEgdR7aEECgqKkJ2djZcXV2ljqMVPAZPRKRHysvLYWdnx3LXMoVCATs7\
# O1nvKWHBExHpGZa7bsh9O7PgiYiIZIgFT0REJEMseCIikp2LFy/ipZdewsiRI7F27Vqp40iCBU9E\
# RA3u9u3bCAkJQXV19T3XuXPnDoKDg1FVVdXgn+/h4YGYmBhs27bNaOcXYcETEVGD27BhA0aMGAGl\
# UnnPdczNzdG3b19s3bpVKxn27NmDJ598En379tXK++s7FjwREdWxadMmeHt7w8fHB+PGjQMAREVF\
# wcvLC15eXli1ahUAoKysDIMHD4aPjw+8vLw0Zf3FF1/gmWee0bxf7969kZCQAAB4++23MX36dADA\
# sGHD8MUXXzxyznu9LwAMHToUp0+ffqz3N2Sc6IaIiGq5cOECIiMjcerUKdjb26O4uBjJycnYuHEj\
# zpw5AyEEAgMDERISgitXrqBVq1bYv38/AODmzZu4c+cOrly5AhcXF817Lly4EO+88w7y8/ORkpKC\
# PXv2AAC8vLzw448/PnLWe73v8ePHsXPnTlRUVODpp59+9I1hwFjwRER6aubMmUhNTW3Q9/T19dWM\
# vu/l6NGjGDlyJOzt7QEAzZo1w+bNmzF8+HA0btwYADBixAicPHkSAwcOxOzZszFnzhwMGTIETz31\
# FHJycmBra1vrPYODgyGEQFRUFI4fP67Zda9UKmFubo5bt27B2tpas36/fv2Ql5dXJ1tkZGStPQP3\
# et9evXqhV69eD7+BZIQFT0REtQgh6kwCc6/7knXo0AHJyck4cOAA5s6di9DQULz66qt1Zog7f/48\
# cnNzYW9vX6vIAaCiogIWFha1liUmJtYr6/3e1+gJ0hsBAQFSRyAiiaWnp0sdQaSlpYn27duLwsJC\
# IYQQRUVFIjk5WXTp0kWUlZWJ0tJS4enpKX766Sdx/fp1cfv2bSGEELt27RLPPPOMEEIIZ2dnzfKc\
# nBzRpUsXkZ6eLvr16ycOHTqk+azCwkLRqVOnR8p5v/etL33Y3trCETwREdXi6emJ+

# %% [markdown]
# Возможные критерии остановки
# $$b - a < \epsilon$$
# $$\vert p_n - p_{n-1} \vert < \epsilon$$
# $$\dfrac{\vert p_n - p_{n-1} \vert}{\vert p_n \vert} < \epsilon$$
# $$\vert f\left(p_n\right)\vert < \epsilon$$

# %% [markdown]
# Оценка сходимости
# $$\vert p_n - p \vert < \frac{1}{2}\left(b_n - a_n\right) = \frac{b-a}{2^n}$$
# $$p_n = p + O\left(\frac{1}{2^n}\right)$$

# %% [markdown]
# #### Метод простой итерации
#
# $$f(x) = 0 \iff x = F(x)$$
# $$x_{n+1} = F(x_n), \quad n = 0, 1, \ldots$$

# %% [markdown]
# **Определение**
#
# Отображение $y = F(x)$ называется сжимающим, если
# $$ \rho(F(x),\;F(y)) \leq q\rho(x,\;y), \quad 0<q<1 \quad \forall x,\;y$$
# $\rho(\cdot\;,\cdot)$ - расстояние. В нормированном пространстве $\rho(x,\;y)=\|x-y\|.$

# %% [markdown]
# **Теорема** О сжимающем отображении
#
# Последовательность $\{x_n\},\; n=0,1,\dots$ элементов $n$-мерного метрического пространства, порожденная итерационным процессом
# $$ x_{n+1} = F(x_n), \quad n = 0, 1, \ldots, \quad x_0 = a$$
# сходится к единственному решению $x^*$ уравнения $x=F(x)$, если отображение
# $$y=F(x)$$
# является сжимающим. При этом справедлива оценка
# $$
# \rho(x_n, x^*) \le \frac{q^n}{1 - q} \rho(x_1, x_0).
# $$

# %% [markdown]
# > Решение $x^*$ уравнения $x = F(x)$ называется *неподвижной точкой отображения*
#
# **Теорема** Достаточное условие сходимости МПИ
#
# Пусть отображение $F : \mathbb{R}^n \to \mathbb{R}^n$ имеет единственную неподвижную точку $x^* = F(x^*)$ и непрерывно дифференцируемо в некоторой её окрестности.
# $$
# J=F'(x) = \left[\begin{array}{ccc}
# \frac{\partial F_1(x)}{\partial x_1} & \ldots & \frac{\partial F_1(x)}{\partial x_n} \\
# \ldots & \ldots & \ldots \\
# \frac{\partial F_n(x)}{\partial x_1} & \ldots & \frac{\partial F_n(x)}{\partial x_n}
# \end{array}\right]
# $$
# Тогда,  если $\|J\| < 1$, то отображение $y=F(x)$ является сжимающим в некоторой окрестности точки $x^*$ и метод простой итерации сходится к $x^*$ для $\forall x_0$ из этой окрестности.

# %% [markdown]
# ##### Метод простой итерации с параметром (Релаксации)
#
# $$ F(x) = x + \tau f(x) $$
# $$ x_{n+1} = x_n + \tau f(x_n), \quad n=0,1,\dots $$

# %%
p = [0.4]

f = lambda x: np.cos(x) - x ** 3 if x is not None else None
fright = lambda x: x + 0.1 * f(x) if x is not None else None

for i in range(15):
    x = p[-1] if p[-1] is not None else p[-2]
    xold = x
    x = fright(x)
    p.append(None)
    p.append(x)
    if np.abs(x - xold) < 1e-4:
        break

count = 0
subcount = 0
p_label = []
for _ in range(len(p)):

    p_label.append(r"$p_{{{}}}$".format(count))

    subcount += 1
    if subcount == 2:
        subcount = 0
        count += 1

fig, ax = plt.subplots(figsize=(8, 6))
ax.spines["left"].set_position("zero")
ax.spines["right"].set_color("none")
ax.yaxis.tick_left()
ax.spines["bottom"].set_position("zero")
ax.spines["top"].set_color("none")
ax.xaxis.tick_bottom()

ax.set_xlim(0, 1.25)
ax.set_ylim(0, 1.25)

x = np.linspace(0.0, 1.25, 100)

lines = []
lines.append(ax.plot(x, fright(x), "k-", label=r"$F(x)$")[0])
lines.append(ax.plot([], [], "k--")[0])
lines.append(ax.plot([], [], "r-")[0])
lines.append(ax.plot([], [], "r-")[0])
lines.append(ax.plot(x, x, "k--")[0])
lines.append(ax.text([], [], "", fontsize=20))
lines.append(ax.plot(x, f(x), "g-", label=r"$\cos(x) - x^3$")[0])

ax.legend(loc='upper left');

def animate(i):

    if p[i] is None:
        lines[2].set_data([p[i - 1], p[i + 1]], [fright(p[i - 1]), p[i + 1]])
        lines[3].set_data([p[i + 1], p[i + 1]], [p[i + 1], fright(p[i + 1])])

    if p[i] is not None:
        lines[1].set_data([p[i], p[i]], [0.0, fright(p[i])])
        if fright(p[i]) > 0:
            lines[5].set_y(fright(p[i]) + 0.05)
            lines[5].set_x(p[i] - 0.05)
            lines[5].set_text(p_label[i])
        else:
            lines[5].set_y(fright(p[i]) - 0.05)
            lines[5].set_x(p[i] - 0.05)
            lines[5].set_text(p_label[i])

    return


plt.close("all")
ani2 = FuncAnimation(fig, animate, frames=len(p), interval=1600)
ani2
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img86ac58734641448387b4ab476e44277b">
#     <br>
#     <input id="_anim_slider86ac58734641448387b4ab476e44277b" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim86ac58734641448387b4ab476e44277b.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim86ac58734641448387b4ab476e44277b.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim86ac58734641448387b4ab476e44277b.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim86ac58734641448387b4ab476e44277b.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim86ac58734641448387b4ab476e44277b.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim86ac58734641448387b4ab476e44277b.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim86ac58734641448387b4ab476e44277b.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim86ac58734641448387b4ab476e44277b.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim86ac58734641448387b4ab476e44277b.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim86ac58734641448387b4ab476e44277b.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select86ac58734641448387b4ab476e44277b" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img86ac58734641448387b4ab476e44277b";
#     var slider_id = "_anim_slider86ac58734641448387b4ab476e44277b";
#     var loop_select_id = "_anim_loop_select86ac58734641448387b4ab476e44277b";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvIxREBQAAIABJREFUeJzs3XdUl+Xj//EnIIh7z3ArqShDcU/c\
# mSniQtQyV5gzK63MPmqOUlNypeYozb3NmdvcguDCQW7coCIom/v3hyd+X3PgAN7C+/U4x+OB9/2+\
# 7hecA7687vu+LgvDMAxEREREzIilqQOIiIiIpDYVIBERETE7KkAiIiJidlSARERExOyoAImIiIjZ\
# UQESERERs6MCJCIiImZHBUhERETMjgqQiIiImB0VIBERETE7KkAiIiJidlSARERExOyoAImIiIjZ\
# UQESERERs6MCJCIiImZHBUhERETMjgqQiIiImB0VIBERETE7KkAiIiJidlSARERExOyoAImIiIjZ\
# UQESERERs6MCJCIiImZHBUhERETMjgqQiIiImB0VIBERETE7KkAiIiJidlSARERExOyoAImIiIjZ\
# UQESERERs6MCJCIiImZHBUhERETMjgqQiIiImB0VIBERETE7KkAiIiJidlSARERExOyoAImIiIjZ\
# UQESERERs6MCJCIiImZHBUhERETMjgqQiIiImB0VIBERETE7KkAiIiJidlSARERExOyoAImIiIjZ\
# UQESERERs6MCJCIiImZHBUhERETMjgqQiIiImB0VIBERETE7KkAiIiJidlSAktCsWTNTRxAREUlR\
# d+7coUWLFlhYWJg6SqrJYOoAb7uQkBBTRxAREUkxvr6+tGzZktDQUCZPnmzqOKlGBUhERMSMFSlS\
# BHt7e3x8fHB2djZ1nFSjS2AiIiJm5vLly3z22WfEx8dToEABdu7caVblB1SAREREzMrKlStxdnZm\
# zpw5nDp1CsCs7v35ly6BvYbY2FiCg4OJiooydZR0zdbWFjs7O6ytrU0dRUQkzYuMjGTQoEHMmDED\
# V1dXlixZQqlSpUwdy2RUgF5DcHAw2bJlo3jx4mbZmlODYRiEhoYSHBxMiRIlTB1HRCTN8/T0ZN26\
# dXzxxReMHj0aGxsbU0cyKV0Cew1RUVHkyZNH5ScFWVhYkCdPHs2yiYi8AcMwiIuLA+Dbb79l06ZN\
# jB8/3uzLD2gG6LWp/KQ8fY9FRF7f/fv36dmzJ4UKFWLy5MlUqVLF1JHeKulmBqhbt27kz5+fChUq\
# PPP1hQsX4ujoiKOjIzVr1uTYsWOpnFBERCR17N+/H2dnZ9asWYOdnR2GYZg60lsn3RSgrl27snnz\
# 5ue+XqJECXbv3s3x48cZNmwYvXr1SsV0IiIiKS8+Pp4xY8ZQt25dLC0t2bt3L4MHD9aM+jOkmwJU\
# t25dcufO/dzXa9asSa5cuQCoXr06wcHBqRUtxcycOZNChQrh7OyMs7MzXbp0ITIyknr16hEfH//c\
# 98XExFC3bt3E68IiIpI+XLlyhdGjR9OuXTv8/f2pVq2aqSO9tczyHqA5c+bw3nvvmTrGGzt+/Dij\
# Ro2ie/fuiZ+bNm0aHh4eWFlZPfd9NjY2NGzYkKVLl9KpU6fUiCoiIinI398fZ2dnSpQoQUBAAKVL\
# l9asTxLSzQzQy9q5cydz5szhxx9/fO4xs2bNwtXVFVdXV+7cuZOK6V7NiRMnnlq5c+HChbRq1Srx\
# Yzc3N7Zu3Qo8fgKgf//+ALi7u7Nw4cLUCysiIskuOjqaQYMGUalSJVasWAFAmTJlVH5eglnNAB0/\
# fpwePXqwadMm8uTJ89zjevXqlXiPkKur6wvHHDhwIAEBAcma09nZGR8fnySPO3XqFB9//DGWlpbk\
# zZuXjRs3cuHCBYoXL554zIgRI/juu++4ffs2/v7+rFu3DoAKFSpw5MiRZM0tIiKpJygoCE9PT44e\
# PUqfPn344IMPTB0pTTGbAnTlyhU8PDxYsGAB9vb2po7zxq5evUrBggU5fvx44ueuX

# %% [markdown]
# #### Метод ньютона
# Пусть нам известно приближенное решение $x_n$ уравнения $f(x) = 0$.
# $$ f(x) \approx f(x_n) + f'(x_n) (x - x_n) $$
# $$ f(x_n) + f'(x_n) (x - x_n) = 0 $$
# В случае, когда <ins>задана функция и известна её производная</ins>
# $$x_{n+1} = x_n - \frac{f(x_n)}{f'\left(x_n\right)}$$
# Для системы
# $$x_{n+1} = x_n - J^{-1}f(x_n)$$
# $$
# J = \left[\begin{array}{ccc}
# \frac{\partial F_1(x)}{\partial x_1} & \ldots & \frac{\partial F_1(x)}{\partial x_n} \\
# \ldots & \ldots & \ldots \\
# \frac{\partial F_n(x)}{\partial x_1} & \ldots & \frac{\partial F_n(x)}{\partial x_n}
# \end{array}\right]
# $$
# Критерий остановки может быть таким
# $$\| x_{n+1} - x_n \| < \epsilon$$

# %%
p = [0.4]

f = lambda x: np.cos(x) - x ** 3 if x is not None else None
fprime = lambda x: -3 * x ** 2 - np.sin(x) if x is not None else None

for i in range(15):

    x = p[-1] if p[-1] is not None else p[-2]

    xold = x
    x = x - f(x) / fprime(x)
    p.append(None)
    p.append(x)

    if np.abs(x - xold) < 1e-4:
        break

count = 0
subcount = 0
p_label = []
for _ in range(len(p)):

    p_label.append(r"$p_{}$".format(count))

    subcount += 1
    if subcount == 2:
        subcount = 0
        count += 1

fig, ax = plt.subplots(figsize=(8, 6))
ax.spines["left"].set_position("zero")
ax.spines["right"].set_color("none")
ax.yaxis.tick_left()
ax.spines["bottom"].set_position("zero")
ax.spines["top"].set_color("none")
ax.xaxis.tick_bottom()

ax.set_xlim(-0.2, 2.0)
ax.set_ylim(-4, 4)

x = np.linspace(-1, 3, 100)

lines = []
lines.append(ax.plot(x, f(x), "k-", label=r"$\cos(x) - x^3$")[0])
lines.append(ax.plot([], [], "k--")[0])
lines.append(ax.plot([], [], "r-")[0])
lines.append(ax.text([], [], "", fontsize=20))


def animate(i):

    lines[1].set_data([p[i], p[i]], [0.0, f(p[i])])
    if p[i] is None:
        lines[2].set_data(x, fprime(p[i - 1]) * (x - p[i - 1]) + f(p[i - 1]))
        lines[3].set_text("")

    if p[i] is not None:
        if f(p[i]) > 0:
            lines[3].set_y(f(p[i]) + 0.2)
            lines[3].set_x(p[i] - 0.05)
            lines[3].set_text(p_label[i])
        else:
            lines[3].set_y(f(p[i]) - 0.4)
            lines[3].set_x(p[i] - 0.05)
            lines[3].set_text(p_label[i])

    return


plt.close("all")
ani2 = FuncAnimation(fig, animate, frames=len(p), interval=1600)
ani2
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img706f6cb360534061a14faca8faf5c1e0">
#     <br>
#     <input id="_anim_slider706f6cb360534061a14faca8faf5c1e0" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim706f6cb360534061a14faca8faf5c1e0.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim706f6cb360534061a14faca8faf5c1e0.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim706f6cb360534061a14faca8faf5c1e0.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim706f6cb360534061a14faca8faf5c1e0.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim706f6cb360534061a14faca8faf5c1e0.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim706f6cb360534061a14faca8faf5c1e0.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim706f6cb360534061a14faca8faf5c1e0.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim706f6cb360534061a14faca8faf5c1e0.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim706f6cb360534061a14faca8faf5c1e0.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim706f6cb360534061a14faca8faf5c1e0.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select706f6cb360534061a14faca8faf5c1e0" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img706f6cb360534061a14faca8faf5c1e0";
#     var slider_id = "_anim_slider706f6cb360534061a14faca8faf5c1e0";
#     var loop_select_id = "_anim_loop_select706f6cb360534061a14faca8faf5c1e0";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvIxREBQAAIABJREFUeJzt3Xl4TfeixvF3J0GooaaQmCOGSIQS\
# pag2JIbiqJqptqbqub0dUJ10PuaiVappbhWl1SqtqCFKgyqKoIgxplSK05iFJDKs+0ePfZoGiZKs\
# lb2+n+fZj2TttZL3d1b26fv81m/v5TAMwxAAAICNuJkdAAAAIL9RgAAAgO1QgAAAgO1QgAAAgO1Q\
# gAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAA\
# gO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1Q\
# gAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAA\
# gO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1Q\
# gAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgAAAgO1QgCwqIyND99xzjzp16mR2FAAAXA4FyKKmTp0q\
# f39/s2MAAOCSKEAWlJCQoGXLlmnw4MFmRwEAwCVRgCzo+eef18SJE+XmxukBACAv8F9Yi1m6dKm8\
# vLzUuHHjm+4XERGh4OBgBQcHKyAgIJ/SAQDgGhyGYRhmh8B/vfLKK5o7d648PDyUkpKiixcv6pFH\
# HtG8efNueExwcLBiYmLyMSUAAAUbBcjC1q5dq0mTJmnp0qU33Y8CBADAreESGAAAsB1mgFwAM0AA\
# ANwaZoAAAIDtUIAAAIDtUIAAAIDtUIAAAIDtUIAAAIDtUIAAAIDtUIAAAIDtUIAAAIDtUIAAAIDt\
# UIAAAIDtUIAAAIDtUIAAAIDtUIAAAIDtUIAAAIDtUIAAAIDtUIAAAIDtUIAAAIDtUIAAAIDtUIAA\
# AIDtUIAAAIDtUIAAAIDtUIAAAIDtUIAAAIDtUIAAAIDtUIAAAIDtUIAAAIDtUIAAAIDtUIAAAIDt\
# UIAAAIDtUIAAAIDtUIAAAIDtUIAAAIDtUIAsJiUlRffee68aNGiggIAAvfnmm2ZHAgDA5XiYHQBZ\
# FSlSRNHR0SpevLjS0tLUsmVLdejQQc2aNTM7GgAALoMZIItxOBwqXry4JCktLU1paWlyOBwmpwIA\
# wLVQgCwoIyNDDRs2lJeXl8LCwtS0aVOzIwEA4FIoQBbk7u6uX375RQkJCdqyZYtiY2Oz7RMREaHg\
# 4GAFBwcrMTHRhJQAABRcDsMwDLND4Mbefvtt3XXXXXrhhRduuE9wcLBiYmLyMRUAAAUbM0AWk5iY\
# qPPnz0uSkpOTtXr1atWtW9fkVAAAuBbeBWYxJ0+e1OOPP66MjAxlZmaqZ8+e6tSpk9mxAABwKRQg\
# iwkKCtKOHTvMjgEAgEvjEhgAALAdChAAALAdChAAALAdChAAALAdChAAALAdChAAALAdChAAALAd\
# ChAAALAdChAAALAdChAAALAdChAAALAdChAAALAdChAAALAdChAAALAdChAAALAdChAAALAdChAA\
# ALAdChAAALAdChAAALAdChAAALAdChAAALAdChAAALAdChAAALAdChAAALAdChAAALAdChAAALAd\
# ChAAALAdChAAALAdChAAALAdChAAALAdChAAALAdCpDFHD9+XCEhIfL391dAQICmTp1qdiQAAFyO\
# h9kBkJWHh4cmT56sRo0a6dKlS2rcuLHCwsJUr149s6MBAOAymAGyGG9vbzVq1EiSVKJECfn7++u3\
# 334zORUAAK6FAmRhx44d044dO9S0aVOzowAA4FK4BGZRSUlJ6tatm95//32VLFky2

# %% [markdown]
# Оценка сходимости
#
# Пусть последовательность приближений $\{x_{k}\}$ сходится к некоторому значению $x^{\star}$.
#
# $$x^\star = x_k + \epsilon_k$$
# Распишем в ряд Тейлора
# \begin{align*}
# 0 = f(x^{\star}) &= f(x_k) + f^\prime(x_k)\epsilon_k + \frac{1}{2} f^{\prime\prime}(\xi_k)
# \end{align*}
# Из метода Ньютона
# $$0 = f(x_k) + f'(x_k)(x_{k+1}-x_k)$$
# Возьмём разницу
# $$f^\prime(x_k)(x^{\star} - x_{k+1}) + \frac{1}{2} f^{\prime\prime}(\xi_k)$$
# Получаем
# \begin{align*}
# \epsilon_{k+1} &= -\frac{f''(\xi_k)}{2f'(x_k)}\epsilon_k^2
# \end{align*}
#
# Получили квадратичную сходимость метода Ньютона при наличии второй производной и отличной от нуля первой производной, что быстрее, чем для методов, рассмотренных ранее.

# %% [markdown]
# **Теорема** Сходимость в $\R$
#
# Пусть $x^*$ - корень уравнения $f(x) = 0$ и
# - $f \in C^2[x^* - \delta, x^* + \delta]$
# - $f'(x) \ne 0$ при $x \in [x^* - \delta, x^* + \delta]$
# - $\gamma \equiv  \frac{\displaystyle  \max_{|x-x^*|\le\delta} \big|f''(x)\big|}{\displaystyle 2 \min_{|x-x^*|\le \delta} \big|f'(x)\big|} \ne 0$
# Тогда $\forall \epsilon:\; 0 < \epsilon < \min\{\delta, \gamma^{-1}\}$ метод Ньютона сходится при любом начальном приближении $x_0 \in [x^*-\epsilon, x^*+\epsilon]$ и верно:
# - $\lvert e_{k+1}\rvert \le \gamma \lvert e_k \rvert^2 $
# - $\lvert e_k \rvert \le \gamma^{-1} (\gamma \lvert e_0 \rvert)^{2^k} $

# %% [markdown]
# **Теорема** Сходимость в $\R^n$
# $$x_{k+1} = x_k - \left[f'(x_k)\right]^{-1} f(x_k)$$
# $f : \mathbb{R}^n \to \mathbb{R}^n$, $f(x^*) = 0$ и в $B_\delta(x^*) = \{x: \Vert x - x^* \Vert \le \delta\}$ $f$ - непрерывно дифференцируемо, якобиан $f$ существует и невырожден, и $\forall x,y \in B_\delta$:
# $$
# \Vert f'(x) - f'(y) \Vert \le c \Vert x - y \Vert, \; c >0
# $$
# Пусть $\displaystyle \gamma = c \max_{\Vert x^* - x\Vert \le \delta} \Vert [f'(x)^{-1}] \Vert$, $0 < \epsilon < \min\{\delta, \gamma^{-1}\}$.
# Тогда $\forall x_0 \in B_\epsilon(x^*)$ метод Ньютона сходится и
# $$
# \begin{align*}
#     \Vert e_{k+1} \Vert \le \gamma \Vert e_k \Vert^2, \quad \Vert e_k \Vert \le \gamma^{-1} (\gamma \Vert e_0 \Vert)^{2^k}
# \end{align*}
# $$

# %% [markdown]
# #### Метод секущих (Хорд)
#
# Попробуем в методе Ньютона заменить производную на её приближенное значение
# $$
# f'(x_{n-1}) = \lim_{x\rightarrow x_{n-1}}\frac{f(x_{n-1})-f(x_{n-2})}{x_{n-2}-x_{n-1}} \approx \frac{f(x_{n-1})-f(x_{n-2})}{x_{n-2}-x_{n-1}}
# $$

# %%
def secant_zero_animate(p0, p1):

    f = lambda x: np.cos(x) - x ** 3 if x is not None else None

    p0 = [p0]
    p1 = [p1]
    pnew = [None]

    q0 = f(p0[-1])
    q1 = f(p1[-1])

    for _ in range(100):
        if p1 is not None and p0 is not None:
            p = p1[-1] - q1 * (p1[-1] - p0[-1]) / (q1 - q0)
        if np.abs(p - p1[-1]) < 0.05:
            break
        p0.append(None)
        p1.append(None)

        if p0[-1] is not None:
            p0.append(p1[-1])
        else:
            p0.append(p1[-2])
        p1.append(p)

        q0 = q1
        q1 = f(p)

        pnew.append(p)
        pnew.append(None)

    count = 0
    subcount = 0
    p0_label = []
    p1_label = []
    pnew_label = []
    for _ in range(len(p0)):

        p0_label.append(r"$p_{}$".format(count))
        p1_label.append(r"$p_{}$".format(count + 1))
        pnew_label.append(r"$p_{}$".format(count + 2))

        subcount += 1
        if subcount == 2:
            subcount = 0
            count += 1

    fig, ax = plt.subplots(figsize=(8, 6))
    ax.spines["left"].set_position("zero")
    ax.spines["right"].set_color("none")
    ax.yaxis.tick_left()
    ax.spines["bottom"].set_position("zero")
    ax.spines["top"].set_color("none")
    ax.xaxis.tick_bottom()

    ax.set_xlim(-0.2, 2.0)
    ax.set_ylim(-4, 4)

    x = np.linspace(-1, 3, 100)

    lines = []
    lines.append(ax.plot(x, f(x), "k-", label=r"$\cos(x) - x^3$")[0])
    lines.append(ax.plot([], [], "r--")[0])
    lines.append(ax.plot([], [], "k--")[0])
    lines.append(ax.plot([], [], "k--")[0])
    lines.append(ax.plot([], [], "r-")[0])
    lines.append(ax.text([], [], "", fontsize=20))
    lines.append(ax.text([], [], "", fontsize=20))
    lines.append(ax.text([], [], "", fontsize=20, color="r"))

    def animate(i):

        if p0[i] is not None:
            lines[2].set_data([p0[i], p0[i]], [0.0, f(p0[i])])
            lines[3].set_data([p1[i], p1[i]], [0.0, f(p1[i])])

            if f(p0[i]) > 0:
                lines[5].set_y(f(p0[i]) + 0.2)
            else:
                lines[5].set_y(f(p0[i]) - 0.5)

            if f(p1[i]) > 0:
                lines[6].set_y(f(p1[i]) + 0.2)
            else:
                lines[6].set_y(f(p1[i]) - 0.5)

            lines[5].set_x(p0[i] - 0.05)
            lines[5].set_text(p0_label[i])
            lines[6].set_x(p1[i] - 0.05)
            lines[6].set_text(p1_label[i])
            lines[7].set_text("")

        else:
            lines[1].set_data([pnew[i], pnew[i]], [0.0, f(pnew[i])])

            if f(pnew[i]) > 0:
                lines[7].set_y(f(pnew[i]) + 0.2)
            else:
                lines[7].set_y(f(pnew[i]) - 0.5)
            lines[7].set_x(pnew[i] - 0.05)
            lines[7].set_text(pnew_label[i])

        if p0[i] is not None:
            lines[4].set_data(
                x, (f(p1[i]) - f(p0[i])) / (p1[i] - p0[i]) * (x - p1[i]) + f(p1[i])
            )

        return

    plt.close("all")
    return FuncAnimation(fig, animate, frames=len(pnew), interval=1600)

# %%
secant_zero_animate(0.1, 1.4)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img551286d0e7da416ba57e806cce428818">
#     <br>
#     <input id="_anim_slider551286d0e7da416ba57e806cce428818" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim551286d0e7da416ba57e806cce428818.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim551286d0e7da416ba57e806cce428818.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim551286d0e7da416ba57e806cce428818.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim551286d0e7da416ba57e806cce428818.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim551286d0e7da416ba57e806cce428818.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim551286d0e7da416ba57e806cce428818.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim551286d0e7da416ba57e806cce428818.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim551286d0e7da416ba57e806cce428818.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim551286d0e7da416ba57e806cce428818.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim551286d0e7da416ba57e806cce428818.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select551286d0e7da416ba57e806cce428818" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img551286d0e7da416ba57e806cce428818";
#     var slider_id = "_anim_slider551286d0e7da416ba57e806cce428818";
#     var loop_select_id = "_anim_loop_select551286d0e7da416ba57e806cce428818";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvIxREBQAAIABJREFUeJzs3XdYlfX/x/HnAdy4DcMtgoggouLI\
# GYqKK82R23Jl42uZacNsWKamZpGjJM2dWjbICFdomitnhhO3pn1zKyqKcP/+uL/yixygAvfhnNfj\
# us4lnHOf+37fHU++rs/9uT9vm2EYBiIiIiJOxMXqAkRERESymgKQiIiIOB0FIBEREXE6CkAiIiLi\
# dBSARERExOkoAImIiIjTUQASERERp6MAJCIiIk5HAUhEREScjgKQiIiIOB0FIBEREXE6CkAiIiLi\
# dBSARERExOkoAImIiIjTUQASERERp6MAJCIiIk5HAUhEREScjgKQiIiIOB0FIBEREXE6CkAiIiLi\
# dBSARERExOkoAImIiIjTUQASERERp6MAJCIiIk5HAUhEREScjgKQiIiIOB0FIBEREXE6CkAiIiLi\
# dBSARERExOkoAImIiIjTUQASERERp6MAJCIiIk5HAUhEREScjgKQiIiIOB0FIBEREXE6CkAiIiLi\
# dBSARERExOkoAImIiIjTUQASERERp6MAJCIiIk5HAUhEREScjgKQiIiIOB0FIBEREXE6CkAiIiLi\
# dBSARERExOkoAImIiIjTUQASERERp6MAZKeSkpKoVq0arVu3troUERERh6MAZKfCw8Px8/OzugwR\
# ERGHpABkh44fP05UVBT9+vWzuhQRERGHpABkhwYNGsTYsWNxcdHHIyIikhn0L6yd+fHHH/Hw8KBG\
# jRp33S4iIoLg4GCCg4Px9/fPoupEREQcg80wDMPqIuT/vf7668yZMwc3NzcSEhK4ePEi7du3Z+7c\
# uXd8T3BwMJs3b87CKkVERLI3BSA7tmrVKsaPH8+PP/541+0UgERERO6NLoGJiIiI09EIkAPQCJCI\
# iMi90QiQiIiIOB0FIBEREXE6CkAiIiLidBSARERExOkoAImIiIjTUQASERERp6MAJCIiIk5HAUhE\
# REScjgKQiIiIOB0FIBEREXE6CkAiIiLidBSARERExOkoAImIiIjTUQASERERp6MAJCIiIk5HAUhE\
# REScjgKQiIiIOB0FIBEREXE6CkAiIiLidBSARERExOkoAImIiIjTUQASERERp6MAJCIiIk5HAUhE\
# REScjgKQiIiIOB0FIBEREXE6CkAiIiLidBSARERExOkoAImIiIjTUQASERERp6MAJCIiIk5HAUhE\
# REScjgKQnUlISKBWrVpUrVoVf39/3n77batLEhERcThuVhcgqeXKlYuYmBjc3d1JTEykfv36tGjR\
# gjp16lhdmoiIiMPQCJCdsdlsuLu7A5CYmEhiYiI2m83iqkRERByLApAdSkpKIigoCA8PD5o2bUrt\
# 2rWtLklERMShKADZIVdXV7Zv387x48f57bffiI2NvWWbiIgIgoODCQ4O5tSpUxZUKSIikn3ZDMMw\
# rC5C7mzEiBHky5ePIUOG3HGb4OBgNm/enIVViYiIZG8aAbIzp06d4vz58wBcvXqVFStWUKlSJYur\
# EhERcSy6C8zOnDx5kieffJKkpCSSk5N54oknaN26tdVliYiIOBQFIDsTGBjItm3brC5DRETEoekS\
# mIiIiDgdBSARERFxOgpAIiIi4nQUgERERMTpKACJiIiI01EAEhEREaejACQiIiJORwFIREREnI4C\
# kIiIiDgdBSARERFxOgpAIiIi4nQUgERERMTpKACJiIiI01EAEhEREaejACQiIiJORwFIREREnI4C\
# kIiIiDgdBSARERFxOgpAIiIi4nQUgERERMTpKACJiIiI01EAEhEREaejACQiIiJORwFIREREnI4C\
# kIiIiDgdBSARERFxOgpAIiIi4nQUgERERMTpKACJiIiI01EAEhEREaejACQiIiJOR

# %% [markdown]
# Порядок сходимости данного метода равен "золотому сечению"
# $$
# \alpha = \frac{1+\sqrt{5}}{2} \approx 1.618
# $$
# т.е.
# $$
# \lim_{k\rightarrow \infty} |\epsilon_{k+1}| \approx С |\epsilon_k|^\alpha
# $$
